# %% [markdown]
# #### Create a dropdown list of city names such as Bangalore,Mangalore,and Mysore using ipywidgets.

# %%
import ipywidgets as wd

options = ['Bangalore','Mangalore','Mysore']

wd.Dropdown(
    options= options,description='Select City'
)
# Out:
# Dropdown(description='Select City', options=('Bangalore', 'Mangalore', 'Mysore'), value='Bangalore')
